# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Compass Community Sessions_Apr 1 2021_Mar 16 2022_LL cleanup (1).csv')
df.head()
# Out:
#    Session Identifier                  Email Internal/External  Searches  \
# 0   16250971533469200  nsaelee@asbhawaii.com          External        13
# 1   16250971533469200  nsaelee@asbhawaii.com          External        13
# 2   16250971533469200  nsaelee@asbhawaii.com          External        13
# 3   16250971533469200  nsaelee@asbhawaii.com          External        13
# 4   16250971533469200  nsaelee@asbhawaii.com          External        13
#
#    Clicks Session Start Time Session last Activity Time  \
# 0       7    6/30/2021 18:52            6/30/2021 22:52
# 1       7    6/30/2021 18:52            6/30/2021 22:52
# 2       7    6/30/2021 18:52            6/30/2021 22:52
# 3       7    6/30/2021 18:52            6/30/2021 22:52
# 4       7    6/30/2021 18:52            6/30/2021 22:52
#
#            Activity Type                                    Activity Detail  \
# 0            Viewed Page  Assigning Governance Group/Workgroup as an own...
# ...

# %%
df1 = df.loc[df['Internal/External'] == 'Internal']

# %%
df2 = df.loc[df['Internal/External'] == 'External']

# %%
df1.to_csv('Internal.csv',index=False)

# %%
df2.to_csv('External.csv',index=False)
